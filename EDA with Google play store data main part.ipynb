# %%
import pandas as pd
import numpy as mp
import seaborn as sns
import matplotlib as plt
df=pd.read_csv("googleplaystore.csv.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.sample(10)
# Out:
#                                              App         Category  Rating  \
# 649                  Healthy Relationships Guide           DATING     NaN
# 7802                              Java Editor CR            TOOLS     3.8
# 8791                            Dr Driving Racer             GAME     4.3
# 3377   Lovely Cute Pink Kitty Cat Keyboard Theme  PERSONALIZATION     4.3
# 1242                          Domino's Pizza USA   FOOD_AND_DRINK     4.7
# 10579                               Fish|Hunt FL        LIFESTYLE     3.6
# 818                          TeachersPayTeachers        EDUCATION     3.8
# 1017                Happy Birthday Songs Offline           EVENTS     4.4
# 1968                                Block Puzzle             GAME     4.6
# 7236                                    CF.lumen            TOOLS     4.4
#
#        Reviews                Size     Installs  Type Price Content Rating  \
# 649          0                8.2M           1+  Free     0       Everyone
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe().T
# Out:
#          count      mean       std  min  25%  50%  75%   max
# Rating  9367.0  4.193338  0.537431  1.0  4.0  4.3  4.5  19.0

# %%
df.describe(include="all").T
# Out:
#                  count unique                 top   freq      mean       std  \
# App              10841   9660              ROBLOX      9       NaN       NaN
# Category         10841     34              FAMILY   1972       NaN       NaN
# Rating          9367.0    NaN                 NaN    NaN  4.193338  0.537431
# Reviews          10841   6002                   0    596       NaN       NaN
# Size             10841    462  Varies with device   1695       NaN       NaN
# Installs         10841     22          1,000,000+   1579       NaN       NaN
# Type             10840      3                Free  10039       NaN       NaN
# Price            10841     93                   0  10040       NaN       NaN
# Content Rating   10840      6            Everyone   8714       NaN       NaN
# Genres           10841    120               Tools    842       NaN       NaN
# Last Updated     10841   1378      August 3, 2018    326       NaN       NaN
# ...

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df["Reviews"]
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: object

# %%
df["Reviews"].shape
# Out:
# (10841,)

# %%
df["Reviews"].dtype
# Out:
# dtype('O')

# %%
df["Reviews"].str.isnumeric()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 10836    True
# 10837    True
# 10838    True
# 10839    True
# 10840    True
# Name: Reviews, Length: 10841, dtype: bool

# %%
df_copy=df.copy()

# %%
df_copy=df_copy.drop(df_copy.index[10472])

# %%
df_copy.shape
# Out:
# (10840, 13)

# %%
df.shape
# Out:
# (10841, 13)

# %%
df_copy["Reviews"]=df_copy["Reviews"].astype("int")

# %%
df_copy["Reviews"].dtype
# Out:
# dtype('int32')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int32(1), object(11)
# memory usage: 1.1+ MB

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_copy["Size"]
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10840, dtype: object

# %%
df_copy["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df_copy["Size"]=df_copy["Size"].str.replace("M","000")

# %%
df_copy["Size"]=df_copy["Size"].str.replace("k","")

# %%
df_copy["Size"].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'Varies with device', '9.4000', '15000', '10000',
#        '1.2000', '26000', '8.0000', '7.9000', '56000', '57000', '35000',
#        '54000', '201', '3.6000', '5.7000', '8.6000', '2.4000', '27000',
#        '2.5000', '16000', '3.4000', '8.9000', '3.9000', '2.9000', '38000',
#        '32000', '5.4000', '18000', '1.1000', '2.2000', '4.5000', '9.8000',
#        '52000', '9.0000', '6.7000', '30000', '2.6000', '7.1000', '3.7000',
#        '22000', '7.4000', '6.4000', '3.2000', '8.2000', '9.9000',
#        '4.9000', '9.5000', '5.0000', '5.9000', '13000', '73000', '6.8000',
#        '3.5000', '4.0000', '2.3000', '7.2000', '2.1000', '42000',
# ...

# %%
df_copy["Size"]=df_copy["Size"].str.replace("Varies with device","NaN")

# %%
df_copy["Size"].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'NaN', '9.4000', '15000', '10000', '1.2000', '26000',
#        '8.0000', '7.9000', '56000', '57000', '35000', '54000', '201',
#        '3.6000', '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000',
#        '3.4000', '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000',
#        '18000', '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
# ...

# %%
df_copy["Size"].dtype
# Out:
# dtype('O')

# %%
df_copy["Size"]=df_copy["Size"].astype("float")

# %%
df_copy["Size"].dtype
# Out:
# dtype('float64')

# %%
df_copy["Size"].head(10)
# Out:
# 0    19000.0
# 1    14000.0
# 2        8.7
# 3    25000.0
# 4        2.8
# 5        5.6
# 6    19000.0
# 7    29000.0
# 8    33000.0
# 9        3.1
# Name: Size, dtype: float64

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_copy["Installs"]
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10840, dtype: object

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_copy["Installs"].str.replace("+","")
# Out:
# 0            10,000
# 1           500,000
# 2         5,000,000
# 3        50,000,000
# 4           100,000
#             ...
# 10836         5,000
# 10837           100
# 10838         1,000
# 10839         1,000
# 10840    10,000,000
# Name: Installs, Length: 10840, dtype: object

# %%
df_copy["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
char_to_removes=["+",",","$"]
cols_to_clean=["Installs","Price"]
for item in char_to_removes:
    for col in cols_to_clean:
        df_copy[col]=df_copy[col].str.replace(item,"")

# %%
df_copy.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews     Size Installs  Type Price Content Rating  \
# 0      159  19000.0    10000  Free     0       Everyone
# 1      967  14000.0   500000  Free     0       Everyone
# 2    87510      8.7  5000000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
df["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int32(1), object(10)
# memory usage: 1.1+ MB

# %%
df_copy["Installs"]=df_copy["Installs"].astype("int")

# %%
df_copy["Installs"].dtype
# Out:
# dtype('int32')

# %%
df_copy["Price"]=df_copy["Price"].astype("float")

# %%
df_copy["Price"].dtype
# Out:
# dtype('float64')

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_copy["Last Updated"]=pd.to_datetime(df_copy["Last Updated"],errors="coerce")

# %%
df_copy["Last Updated"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df_copy["Last Updated"].dt.date
# Out:
# 0        2018-01-07
# 1        2018-01-15
# 2        2018-08-01
# 3        2018-06-08
# 4        2018-06-20
#             ...
# 10836    2017-07-25
# 10837    2018-07-06
# 10838    2017-01-20
# 10839    2015-01-19
# 10840    2018-07-25
# Name: Last Updated, Length: 10840, dtype: object

# %%
df_copy["Last Updated"].dt.month
# Out:
# 0        1
# 1        1
# 2        8
# 3        6
# 4        6
#         ..
# 10836    7
# 10837    7
# 10838    1
# 10839    1
# 10840    7
# Name: Last Updated, Length: 10840, dtype: int32

# %%
df_copy["Last Updated"].dt.year
# Out:
# 0        2018
# 1        2018
# 2        2018
# 3        2018
# 4        2018
#          ...
# 10836    2017
# 10837    2018
# 10838    2017
# 10839    2015
# 10840    2018
# Name: Last Updated, Length: 10840, dtype: int32

# %%
df_copy.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver
# 0               Art & Design   2018-01-07       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01       1.2.4  4.0.3 and up

# %%
df_copy["Android Ver"]=df_copy["Android Ver"].str.replace("and up","")

# %%
df_copy["Android Ver"]=df_copy["Android Ver"].str.replace("Varies with device","NaN")

# %%
df_copy["Android Ver"]
# Out:
# 0        4.0.3
# 1        4.0.3
# 2        4.0.3
# 3          4.2
# 4          4.4
#           ...
# 10836      4.1
# 10837      4.1
# 10838      2.2
# 10839       NaN
# 10840       NaN
# Name: Android Ver, Length: 10840, dtype: object

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
df_copy.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10836     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10837     5.0        4      3.6       100  Free    0.0       Everyone
# 10838     NaN        3      9.5      1000  Free    0.0       Everyone
# 10839     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10840     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver Android Ver
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
df_copy.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10836     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10837     5.0        4      3.6       100  Free    0.0       Everyone
# 10838     NaN        3      9.5      1000  Free    0.0       Everyone
# 10839     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10840     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver Android Ver
# ...

# %%
df_copy.sample(5)
# Out:
#                                             App         Category  Rating  \
# 3352                              Nova Launcher  PERSONALIZATION     4.6
# 9149               Star Wars™: Galaxy of Heroes           FAMILY     4.5
# 9277                EF English Live for tablets           FAMILY     3.1
# 1815                TerraGenesis - Space Colony             GAME     4.3
# 803   Mango Languages: Lovable Language Courses        EDUCATION     4.0
#
#       Reviews     Size  Installs  Type  Price Content Rating           Genres  \
# 3352  1121805      NaN  50000000  Free    0.0       Everyone  Personalization
# 9149  1461698  67000.0  10000000  Free    0.0   Everyone 10+     Role Playing
# 9277     1242  14000.0     50000  Free    0.0       Everyone        Education
# 1815    38957      NaN   1000000  Free    0.0       Everyone       Simulation
# 803      4815  19000.0    500000  Free    0.0       Everyone        Education
#
#      Last Updated         Current Ver Android Ver
# ...

# %%
df_copy.shape
# Out:
# (10840, 13)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int32
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: datetime64[ns](1), float64(3), int32(2), object(7)
# memory usage: 1.1+ MB

# %%
df_copy.describe()
# Out:
#             Rating       Reviews           Size      Installs         Price  \
# count  9366.000000  1.084000e+04    9145.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05   19579.419913  1.546434e+07      1.027368
# min       1.000000  0.000000e+00       1.000000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01       5.600000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   13000.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04   30000.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09    400.000000
# std       0.515219  2.927761e+06   24042.062020  8.502936e+07     15.949703
#
#                         Last Updated
# count                          10840
# mean   2017-11-21 06:43:02.435424256
# min              2010-05-21 00:00:00
# 25%              2017-09-20 00:00:00
# 50%              2018-05-24 00:00:00
# 75%              2018-07-20 00:00:00
# ...

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_copy[df_copy.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df_copy[df_copy.duplicated("App")]
# Out:
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10715                  FarmersOnly Dating         DATING     3.0     1145
# 10720  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10730                         FP Notebook        MEDICAL     4.5      410
# 10753      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10768                                AAFP        MEDICAL     3.8       63
#
#           Size  Installs  Type  Price Content Rating         Genres  \
# ...

# %%
df_copy=df_copy[df_copy.duplicated(subset=["App"],keep="first")]

# %%
df_copy.shape
# Out:
# (1181, 13)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1181 entries, 229 to 10768
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             1181 non-null   object
#  1   Category        1181 non-null   object
#  2   Rating          1170 non-null   float64
#  3   Reviews         1181 non-null   int32
#  4   Size            713 non-null    float64
#  5   Installs        1181 non-null   int32
#  6   Type            1181 non-null   object
#  7   Price           1181 non-null   float64
#  8   Content Rating  1181 non-null   object
#  9   Genres          1181 non-null   object
#  10  Last Updated    1181 non-null   datetime64[ns]
#  11  Current Ver     1181 non-null   object
#  12  Android Ver     1181 non-null   object
# dtypes: datetime64[ns](1), float64(3), int32(2), object(7)
# memory usage: 119.9+ KB

# %%
numeric_features=[feature for feature in df.columns if df[feature].dtype !="O"]

# %%
df_copy[numeric_features]
# Out:
#        Rating
# 229       4.2
# 236       4.2
# 239       4.4
# 256       4.4
# 261       4.0
# ...       ...
# 10715     3.0
# 10720     4.4
# 10730     4.5
# 10753     4.5
# 10768     3.8
#
# [1181 rows x 1 columns]

# %%
categorical_features=[feature for feature in df.columns if df[feature].dtype=="O"]

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df_copy["Reviews"]=df_copy["Reviews"].astype("int64")

# %%
df_copy["Reviews"].dtype
# Out:
# dtype('int64')

# %%
numeric_features=[feature for feature in df.columns if df[feature].dtype !="O"]

# %%
df_copy[numeric_features]
# Out:
#        Rating
# 229       4.2
# 236       4.2
# 239       4.4
# 256       4.4
# 261       4.0
# ...       ...
# 10715     3.0
# 10720     4.4
# 10730     4.5
# 10753     4.5
# 10768     3.8
#
# [1181 rows x 1 columns]

# %%
df_copy[categorical_features]
# Out:
#                                       App       Category  Reviews     Size  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS    80805      NaN
# 236                                   Box       BUSINESS   159872      NaN
# 239                    Google My Business       BUSINESS    70991      NaN
# 256                   ZOOM Cloud Meetings       BUSINESS    31614  37000.0
# 261             join.me - Simple Meetings       BUSINESS     6989      NaN
# ...                                   ...            ...      ...      ...
# 10715                  FarmersOnly Dating         DATING     1145      1.4
# 10720  Firefox Focus: The privacy browser  COMMUNICATION    36981      4.0
# 10730                         FP Notebook        MEDICAL      410  60000.0
# 10753      Slickdeals: Coupons & Shopping       SHOPPING    33599  12000.0
# 10768                                AAFP        MEDICAL       63  24000.0
#
# ...

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df_copy["Type"].value_counts()
# Out:
# Type
# Free    1137
# Paid      44
# Name: count, dtype: int64

# %% [markdown]
# # To get the value counts in percentage manner

# %%
df_copy["Type"].value_counts(normalize=True)*100
# Out:
# Type
# Free    96.274344
# Paid     3.725656
# Name: proportion, dtype: float64

# %%
for i in categorical_features:
    print(i)
# Out:
# App
# Category
# Reviews
# Size
# Installs
# Type
# Price
# Content Rating
# Genres
# Last Updated
# Current Ver
# Android Ver

# %%
sns.countplot(x=df["Type"])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.countplot(x=df["Content Rating"])
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
df_copy.head(10)
# Out:
#                               App  Category  Rating  Reviews     Size  \
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2    80805      NaN
# 236                           Box  BUSINESS     4.2   159872      NaN
# 239            Google My Business  BUSINESS     4.4    70991      NaN
# 256           ZOOM Cloud Meetings  BUSINESS     4.4    31614  37000.0
# 261     join.me - Simple Meetings  BUSINESS     4.0     6989      NaN
# 265                           Box  BUSINESS     4.2   159872      NaN
# 266                      Zenefits  BUSINESS     4.2      296  14000.0
# 267                    Google Ads  BUSINESS     4.3    29313  20000.0
# 268            Google My Business  BUSINESS     4.4    70991      NaN
# 269                         Slack  BUSINESS     4.4    51507      NaN
#
#      Installs  Type  Price Content Rating    Genres Last Updated  \
# 229   5000000  Free    0.0       Everyone  Business   2018-02-26
# ...

# %% [markdown]
# # category wise countplots

# %%
plt.figure(figsize=(20,15))
plt.suptitle("Univariate Analysis of Categorical features",fontsize=20,fontweight="bold",alpha=0.8,y=1.)
category=["Type","Content Rating"]
for i in range(0,len(category)):
    plt.subplot(2,2,i+1)
    sns.countplot(x=df[category[i]])
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
numeric_features
# Out:
# ['Rating']

# %%
df_copy.head()
# Out:
#                               App  Category  Rating  Reviews     Size  \
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2    80805      NaN
# 236                           Box  BUSINESS     4.2   159872      NaN
# 239            Google My Business  BUSINESS     4.4    70991      NaN
# 256           ZOOM Cloud Meetings  BUSINESS     4.4    31614  37000.0
# 261     join.me - Simple Meetings  BUSINESS     4.0     6989      NaN
#
#      Installs  Type  Price Content Rating    Genres Last Updated  \
# 229   5000000  Free    0.0       Everyone  Business   2018-02-26
# 236  10000000  Free    0.0       Everyone  Business   2018-07-31
# 239   5000000  Free    0.0       Everyone  Business   2018-07-24
# 256  10000000  Free    0.0       Everyone  Business   2018-07-20
# 261   1000000  Free    0.0       Everyone  Business   2018-07-16
#
#             Current Ver Android Ver
# 229  Varies with device      4.0.3
# 236  Varies with device         NaN
# 239    2.19.0.204537701        4.4
# ...

# %%
sns.kdeplot(df["Rating"])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
plt.figure(figsize=(15,15))
plt.suptitle("Univariate Analysis of Numerical features",fontsize=20,fontweight="bold",alpha=0.8,y=1.)

for i in range(0,len(numeric_features)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df[numeric_features[i]])
    plt.xlabel(numeric_features[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %% [markdown]
# # most popular category in app

# %%
df_copy.head()
# Out:
#                               App  Category  Rating  Reviews     Size  \
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2    80805      NaN
# 236                           Box  BUSINESS     4.2   159872      NaN
# 239            Google My Business  BUSINESS     4.4    70991      NaN
# 256           ZOOM Cloud Meetings  BUSINESS     4.4    31614  37000.0
# 261     join.me - Simple Meetings  BUSINESS     4.0     6989      NaN
#
#      Installs  Type  Price Content Rating    Genres Last Updated  \
# 229   5000000  Free    0.0       Everyone  Business   2018-02-26
# 236  10000000  Free    0.0       Everyone  Business   2018-07-31
# 239   5000000  Free    0.0       Everyone  Business   2018-07-24
# 256  10000000  Free    0.0       Everyone  Business   2018-07-20
# 261   1000000  Free    0.0       Everyone  Business   2018-07-16
#
#             Current Ver Android Ver
# 229  Varies with device      4.0.3
# 236  Varies with device         NaN
# 239    2.19.0.204537701        4.4
# ...

# %% [markdown]
# # Most popular category Apps

# %%
df_copy["Category"].value_counts().plot.pie(y=df["Category"],figsize=(25,25))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Top 10 category Apps

# %%
df_copy["Category"].value_counts()[:10]
# Out:
# Category
# GAME                  185
# FAMILY                140
# COMMUNICATION          72
# MEDICAL                68
# DATING                 63
# SPORTS                 59
# SHOPPING               58
# SOCIAL                 56
# PHOTOGRAPHY            54
# HEALTH_AND_FITNESS     53
# Name: count, dtype: int64

# %% [markdown]
# # Top 10 category Apps in Graph

# %%
df_cat=df_copy["Category"].value_counts()[:10]

# %%
category=pd.Dataframe(df_copy["Category"].value_counts())
category.rename(columns={"category":"Count"},inplace = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 category=pd.Dataframe(df_copy["Category"].value_counts())
#       2 category.rename(columns={"category":"Count"},inplace = True)
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df_cat,y="Count",data=category[:10],palette="hls")
for i in range(0,len(numeric_features)):
    plt.title("Top 10 App categories")
    plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 2
#       1 plt.figure(figsize=(15,6))
# ----> 2 sns.barplot(x=df_cat,y="Count",data=category[:10],palette="hls")
#       3 for i in range(0,len(numeric_features)):
#       4     plt.title("Top 10 App categories")
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
# ...

# %%
#which category having a largest number of installation.

# %%
df_copy.head(3)
# Out:
#                               App  Category  Rating  Reviews  Size  Installs  \
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2    80805   NaN   5000000
# 236                           Box  BUSINESS     4.2   159872   NaN  10000000
# 239            Google My Business  BUSINESS     4.4    70991   NaN   5000000
#
#      Type  Price Content Rating    Genres Last Updated         Current Ver  \
# 229  Free    0.0       Everyone  Business   2018-02-26  Varies with device
# 236  Free    0.0       Everyone  Business   2018-07-31  Varies with device
# 239  Free    0.0       Everyone  Business   2018-07-24    2.19.0.204537701
#
#     Android Ver
# 229      4.0.3
# 236         NaN
# 239        4.4

# %%
df_copy.groupby(["Category"])["Installs"].sum().sort_values()

# %%
df2=df_copy.groupby(["Category"])["Installs"].sum().sort_values(ascending=False).reset_index()
df2

# %%
df2.head(10)

# %%
sns.barplot(x="Installs",y="Category",data=df2)

# %% [markdown]
# # what are the top five most installed apps in each popular categories ??

# %%
df3=df_copy.groupby(["Category","App"])["Installs"].sum().sort_values(ascending=False).reset_index()
df3
# Out:
#                Category                             App    Installs
# 0                  GAME                  Subway Surfers  5000000000
# 1          PRODUCTIVITY                    Google Drive  3000000000
# 2           PHOTOGRAPHY                   Google Photos  3000000000
# 3    NEWS_AND_MAGAZINES                     Google News  3000000000
# 4         COMMUNICATION                        Hangouts  3000000000
# ..                  ...                             ...         ...
# 822              DATING  Chat Kids - Chat Room For Kids         100
# 823             MEDICAL          420 BZ Budeze Delivery         100
# 824             MEDICAL  Breastfeeding Tracker Baby Log         100
# 825             MEDICAL      Penn State Health OnDemand          50
# 826             MEDICAL                      RT 516 VET          10
#
# [827 rows x 3 columns]

# %%
df3.head(5)
# Out:
#              Category             App    Installs
# 0                GAME  Subway Surfers  5000000000
# 1        PRODUCTIVITY    Google Drive  3000000000
# 2         PHOTOGRAPHY   Google Photos  3000000000
# 3  NEWS_AND_MAGAZINES     Google News  3000000000
# 4       COMMUNICATION        Hangouts  3000000000

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="Installs",y="App",data=df3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 2
#       1 plt.figure(figsize=(5,5))
# ----> 2 sns.barplot(x="Installs",y="App",data=df3)
#
# NameError: name 'df3' is not defined

# %%
df_copy.head()
# Out:
#                               App  Category  Rating  Reviews     Size  \
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2    80805      NaN
# 236                           Box  BUSINESS     4.2   159872      NaN
# 239            Google My Business  BUSINESS     4.4    70991      NaN
# 256           ZOOM Cloud Meetings  BUSINESS     4.4    31614  37000.0
# 261     join.me - Simple Meetings  BUSINESS     4.0     6989      NaN
#
#      Installs  Type  Price Content Rating    Genres Last Updated  \
# 229   5000000  Free    0.0       Everyone  Business   2018-02-26
# 236  10000000  Free    0.0       Everyone  Business   2018-07-31
# 239   5000000  Free    0.0       Everyone  Business   2018-07-24
# 256  10000000  Free    0.0       Everyone  Business   2018-07-20
# 261   1000000  Free    0.0       Everyone  Business   2018-07-16
#
#             Current Ver Android Ver
# 229  Varies with device      4.0.3
# 236  Varies with device         NaN
# 239    2.19.0.204537701        4.4
# ...

# %% [markdown]
# # Apps whichever having only 5 ratings

# %%
rating=df.groupby(["App"])["Rating"].sum().sort_values(ascending=False).reset_index()
rating
# Out:
#                                                     App  Rating
# 0                                                ROBLOX    40.5
# 1     CBS Sports App - Scores, News, Stats & Watch Live    34.4
# 2                        Duolingo: Learn Languages Free    32.9
# 3                                           8 Ball Pool    31.5
# 4                                      Candy Crush Saga    30.8
# ...                                                 ...     ...
# 9655                                  BL 1-Click Camera     0.0
# 9656                                BK Travel Solutions     0.0
# 9657  Love Calendar - Couple Sharing Calendar & Coup...     0.0
# 9658                                              Luffs     0.0
# 9659               "i DT" Fútbol. Todos Somos Técnicos.     0.0
#
# [9660 rows x 2 columns]

# %%
df_copy["Rating"]
# Out:
# 229      4.2
# 236      4.2
# 239      4.4
# 256      4.4
# 261      4.0
#         ...
# 10715    3.0
# 10720    4.4
# 10730    4.5
# 10753    4.5
# 10768    3.8
# Name: Rating, Length: 1181, dtype: float64

# %%
rating[rating.Rating==5.0]
# Out:
#                              App  Rating
# 789               EC Fairgrounds     5.0
# 790   Dine In CT - Food Delivery     5.0
# 791        NOMISMA.com.cy by FMW     5.0
# 792                    CP Trivia     5.0
# 793    HON. B.J. ACS COLLEGE ALE     5.0
# ...                          ...     ...
# 1053                      AJ Cam     5.0
# 1054   Cy-Fair VFD EMS Protocols     5.0
# 1055                  EF Academy     5.0
# 1056      Quran Khmer Offline AY     5.0
# 1057           AJ Blue Icon Pack     5.0
#
# [269 rows x 2 columns]

# %%
rating2=df.groupby(["Category","Installs","App"])["Rating"].sum().sort_values(ascending=False).reset_index()
rating2
# Out:
#                 Category      Installs  \
# 0                 SPORTS    5,000,000+
# 1                 SPORTS   10,000,000+
# 2                   GAME   10,000,000+
# 3                   GAME   50,000,000+
# 4                   GAME  100,000,000+
# ...                  ...           ...
# 9748  NEWS_AND_MAGAZINES           50+
# 9749  NEWS_AND_MAGAZINES           50+
# 9750  NEWS_AND_MAGAZINES           50+
# 9751  NEWS_AND_MAGAZINES           50+
# 9752            BUSINESS           50+
#
#                                                     App  Rating
# 0     CBS Sports App - Scores, News, Stats & Watch Live    34.4
# 1                                                  ESPN    29.4
# 2                                       Zombie Catchers    28.2
# 3                                            Bowmasters    28.2
# 4      Sniper 3D Gun Shooter: Free Shooting Games - FPS    27.6
# ...                                                 ...     ...
# ...

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df_copy,y="Category",x="Price")
# Out:
# <Axes: xlabel='Price', ylabel='Category'>

# %% [markdown]
# # which category apps users are reviewing the most.

# %%
rating2=df.groupby(["Category","Reviews"])["App"].sum().sort_values(ascending=False).reset_index()
rating2
# Out:
#                 Category Reviews  \
# 0          ENTERTAINMENT   11661
# 1                 SOCIAL   22098
# 2              LIFESTYLE     718
# 3          VIDEO_PLAYERS     414
# 4                 COMICS     190
# ...                  ...     ...
# 7983  NEWS_AND_MAGAZINES      27
# 7984       COMMUNICATION     573
# 7985               TOOLS     259
# 7986              COMICS     115
# 7987              SOCIAL   40467
#
#                                                    App
# 0     🔥 Football Wallpapers 4K | Full HD Backgrounds 😍
# 1        💘 WhatsLov: Smileys of love, stickers and GIF
# 2                                           💎 I'm rich
# 3                              뽕티비 - 개인방송, 인터넷방송, BJ방송
# 4                                          감성학원 BL 첫사랑
# ...                                                ...
# 7983                                    058.baCy-Ranch
# 7984                                            /u/app
# 7985                                                .R
# ...

# %%
df_copy.head(1)
# Out:
#                               App  Category  Rating  Reviews  Size  Installs  \
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2    80805   NaN   5000000
#
#      Type  Price Content Rating    Genres Last Updated         Current Ver  \
# 229  Free    0.0       Everyone  Business   2018-02-26  Varies with device
#
#     Android Ver
# 229      4.0.3

# %%
df.groupby("Type").agg({"Installs":sum}).plot.pie(y="Installs")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 df.groupby("Type").agg({"Installs":sum}).plot.pie(y="Installs")
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1589, in PlotAccessor.pie(self, **kwargs)
#    1583 if (
#    1584     isinstance(self._parent, ABCDataFrame)
#    1585     and kwargs.get("y", None) is None
#    1586     and not kwargs.get("subplots", False)
#    1587 ):
#    1588     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1589 return self(kind="pie", **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
plt.figure(figsize=(20,20))
sns.boxplot(x="Installs",y="Rating",data=df_copy)
# Out:
# <Axes: xlabel='Installs', ylabel='Rating'>

# %% [markdown]
# # which category are of largest size

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
rating2=df.groupby(["Category"])["Size"].sum().sort_values(ascending=False).reset_index()
rating2
# Out:
#                Category                                               Size
# 0                SOCIAL  Varies with deviceVaries with deviceVaries wit...
# 1              BUSINESS  Varies with deviceVaries with deviceVaries wit...
# 2          PRODUCTIVITY  Varies with deviceVaries with deviceVaries wit...
# 3   MAPS_AND_NAVIGATION  Varies with deviceVaries with deviceVaries wit...
# 4               FINANCE  Varies with deviceVaries with device42MVaries ...
# 5         COMMUNICATION  Varies with deviceVaries with device17MVaries ...
# 6    NEWS_AND_MAGAZINES  Varies with deviceVaries with device16M26MVari...
# 7                SPORTS  Varies with device9.8MVaries with deviceVaries...
# 8                DATING  Varies with device6.2M20M18k1.2M17MVaries with...
# 9         VIDEO_PLAYERS  Varies with device5.6M5.4M2.9M25MVaries with d...
# 10  BOOKS_AND_REFERENCE  Varies with device4.9M9.5MVaries with deviceVa...
# ...

# %%
plt.figure(figsize=(20,20))
sns.barplot(x="Category",y="Size",data=df_copy)
plt.xticks(rotation=90)
plt.show()
